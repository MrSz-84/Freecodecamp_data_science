# %%
import numpy as np
import pandas as pd

# %%
column_names = ['color', 'director_name', 'num_critic_for_reviews', 'duration',
                'gross', 'movie_title', 'num_user_for_reviews',	'country',
                'cotent_rating', 'budget', 'title_year', 'imdb_score', 'genre']

# %%
path = 'files/movies.csv'
df = pd.read_csv(path, delimiter='|', header=None, names=column_names, skiprows=3, na_values='?', thousands=',')
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration        gross  \
# 0  Color  Christopher Nolan                   813.0     164.0  448130642.0
# 1    NaN        Doug Walker                     NaN       NaN          NaN
# 2  Color     Andrew Stanton                   462.0     132.0   73058679.0
# 3  Color          Sam Raimi                   392.0     156.0  336530303.0
# 4  Color       Nathan Greno                   324.0     100.0  200807262.0
#
#                                          movie_title  num_user_for_reviews  \
# 0                             The Dark Knight Rises                 2701.0
# 1  Star Wars: Episode VII - The Force Awakens    ...                   NaN
# 2                                       John Carter                  738.0
# 3                                      Spider-Man 3                 1902.0
# 4                                           Tangled                  387.0
#
#   country cotent_rating       budget  title_year  imdb_score        genre
# 0     USA         PG-13  250000000.0      2012.0         8.5       Action
# 1     NaN           NaN          NaN         NaN         7.1  Documentary
# 2     USA         PG-13  263700000.0      2012.0         6.6       Action
# 3     USA         PG-13  258000000.0      2007.0         6.2       Action
# 4     USA            PG  260000000.0      2010.0         7.8    Adventure

# %%
df['color'].fillna(method='ffill', inplace=True)

# %%
df
# Out:
#     color      director_name  num_critic_for_reviews  duration        gross  \
# 0   Color  Christopher Nolan                   813.0     164.0  448130642.0
# 1     NaN        Doug Walker                     NaN       NaN          NaN
# 2   Color     Andrew Stanton                   462.0     132.0   73058679.0
# 3   Color          Sam Raimi                   392.0     156.0  336530303.0
# 4   Color       Nathan Greno                   324.0     100.0  200807262.0
# ..    ...                ...                     ...       ...          ...
# 92  Color         James Gunn                   653.0     121.0  333130696.0
# 93  Color  Christopher Nolan                   712.0     169.0  187991439.0
# 94  Color  Christopher Nolan                   642.0     148.0  292568851.0
# 95  Color       Hideaki Anno                     1.0     120.0          NaN
# 96  Color      Peter Jackson                   645.0     182.0  303001229.0
#
#                                           movie_title  num_user_for_reviews  \
# 0                              The Dark Knight Rises                 2701.0
# 1   Star Wars: Episode VII - The Force Awakens    ...                   NaN
# 2                                        John Carter                  738.0
# 3                                       Spider-Man 3                 1902.0
# 4                                            Tangled                  387.0
# ..                                                ...                   ...
# 92                           Guardians of the Galaxy                 1097.0
# 93                                      Interstellar                 2725.0
# 94                                         Inception                 2803.0
# 95                               Godzilla Resurgence                   13.0
# 96                 The Hobbit: An Unexpected Journey                 1367.0
#
#    country cotent_rating       budget  title_year  imdb_score        genre
# 0      USA         PG-13  250000000.0      2012.0         8.5       Action
# 1      NaN           NaN          NaN         NaN         7.1  Documentary
# 2      USA         PG-13  263700000.0      2012.0         6.6       Action
# 3      USA         PG-13  258000000.0      2007.0         6.2       Action
# 4      USA            PG  260000000.0      2010.0         7.8    Adventure
# ..     ...           ...          ...         ...         ...          ...
# 92     USA         PG-13  170000000.0      2014.0         8.1       Action
# 93     USA         PG-13  165000000.0      2014.0         8.6    Adventure
# 94     USA         PG-13  160000000.0      2010.0         8.8       Action
# 95   Japan           NaN          NaN      2016.0         8.2       Action
# 96     USA         PG-13  180000000.0      2012.0         7.9    Adventure
#
# [97 rows x 13 columns]

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 0 to 96
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   color                   93 non-null     object
#  1   director_name           93 non-null     object
#  2   num_critic_for_reviews  93 non-null     float64
#  3   duration                93 non-null     float64
#  4   gross                   93 non-null     float64
#  5   movie_title             93 non-null     object
#  6   num_user_for_reviews    93 non-null     float64
#  7   country                 93 non-null     object
#  8   cotent_rating           93 non-null     object
#  9   budget                  93 non-null     float64
#  10  title_year              93 non-null     float64
#  11  imdb_score              93 non-null     float64
#  12  genre                   93 non-null     object
# dtypes: float64(7), object(6)
# memory usage: 10.2+ KB

# %%
df
# Out:
#     color      director_name  num_critic_for_reviews  duration        gross  \
# 0   Color  Christopher Nolan                   813.0     164.0  448130642.0
# 2   Color     Andrew Stanton                   462.0     132.0   73058679.0
# 3   Color          Sam Raimi                   392.0     156.0  336530303.0
# 4   Color       Nathan Greno                   324.0     100.0  200807262.0
# 5   Color        Joss Whedon                   635.0     141.0  458991599.0
# ..    ...                ...                     ...       ...          ...
# 91  Color    Jonathan Mostow                   280.0     109.0  150350192.0
# 92  Color         James Gunn                   653.0     121.0  333130696.0
# 93  Color  Christopher Nolan                   712.0     169.0  187991439.0
# 94  Color  Christopher Nolan                   642.0     148.0  292568851.0
# 96  Color      Peter Jackson                   645.0     182.0  303001229.0
#
#                             movie_title  num_user_for_reviews country  \
# 0                The Dark Knight Rises                 2701.0     USA
# 2                          John Carter                  738.0     USA
# 3                         Spider-Man 3                 1902.0     USA
# 4                              Tangled                  387.0     USA
# 5              Avengers: Age of Ultron                 1117.0     USA
# ..                                  ...                   ...     ...
# 91  Terminator 3: Rise of the Machines                 1676.0     USA
# 92             Guardians of the Galaxy                 1097.0     USA
# 93                        Interstellar                 2725.0     USA
# 94                           Inception                 2803.0     USA
# 96   The Hobbit: An Unexpected Journey                 1367.0     USA
#
#    cotent_rating       budget  title_year  imdb_score      genre
# 0          PG-13  250000000.0      2012.0         8.5     Action
# 2          PG-13  263700000.0      2012.0         6.6     Action
# 3          PG-13  258000000.0      2007.0         6.2     Action
# 4             PG  260000000.0      2010.0         7.8  Adventure
# 5          PG-13  250000000.0      2015.0         7.5     Action
# ..           ...          ...         ...         ...        ...
# 91             R  200000000.0      2003.0         6.4     Action
# 92         PG-13  170000000.0      2014.0         8.1     Action
# 93         PG-13  165000000.0      2014.0         8.6  Adventure
# 94         PG-13  160000000.0      2010.0         8.8     Action
# 96         PG-13  180000000.0      2012.0         7.9  Adventure
#
# [93 rows x 13 columns]
