# %%
import pandas as pd
import numpy as np

# %%
data_url = 'https://github.com/ine-rmotr-projects/project-files/files/4086772/playstore.xlsx'

# %%
playstore_df = pd.read_excel(data_url,
                             sheet_name='Google_playstore',
                             index_col=1
                            )

# %%
playstore_df
# Out:
#                                                     Unnamed: 0  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook               0
# Coloring book moana                                          1
# U Launcher Lite – FREE Live Cool Themes, Hide Apps           2
# Sketch - Draw & Paint                                        3
# Pixel Draw - Number Art Coloring Book                        4
# ...                                                        ...
# Xero Accounting Software                                   245
# MailChimp - Email, Marketing Automation                    246
# Crew - Free Messaging and Scheduling                       247
# Asana: organize team projects                              248
# Google Analytics                                           249
#
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
# ...                                                            ...     ...
# Xero Accounting Software                                  BUSINESS     3.5
# MailChimp - Email, Marketing Automation                   BUSINESS     4.1
# Crew - Free Messaging and Scheduling                      BUSINESS     4.6
# Asana: organize team projects                             BUSINESS     4.3
# Google Analytics                                          BUSINESS     4.5
#
#                                                        Installs  Type Price  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook          10,000+  Free     0
# Coloring book moana                                    500,000+  Free     0
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   5,000,000+  Free     0
# Sketch - Draw & Paint                               50,000,000+  Free     0
# Pixel Draw - Number Art Coloring Book                  100,000+  Free     0
# ...                                                         ...   ...   ...
# Xero Accounting Software                               100,000+  Free     0
# MailChimp - Email, Marketing Automation                500,000+  Free     0
# Crew - Free Messaging and Scheduling                   500,000+  Free     0
# Asana: organize team projects                        1,000,000+  Free     0
# Google Analytics                                     1,000,000+  Free     0
#
#                                                     Content_ID  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook             101
# Coloring book moana                                        101
# U Launcher Lite – FREE Live Cool Themes, Hide Apps         101
# Sketch - Draw & Paint                                      102
# Pixel Draw - Number Art Coloring Book                      101
# ...                                                        ...
# Xero Accounting Software                                   101
# MailChimp - Email, Marketing Automation                    101
# Crew - Free Messaging and Scheduling                       101
# Asana: organize team projects                              101
# Google Analytics                                           101
#
#                                                                        Genres  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook                   Art & Design
# Coloring book moana                                 Art & Design;Pretend Play
# U Launcher Lite – FREE Live Cool Themes, Hide Apps               Art & Design
# Sketch - Draw & Paint                                            Art & Design
# Pixel Draw - Number Art Coloring Book                 Art & Design;Creativity
# ...                                                                       ...
# Xero Accounting Software                                             Business
# MailChimp - Email, Marketing Automation                              Business
# Crew - Free Messaging and Scheduling                                 Business
# Asana: organize team projects                                        Business
# Google Analytics                                                     Business
#
#                                                          Last_Updated
# App
# Photo Editor & Candy Camera & Grid & ScrapBook        January 7, 2018
# Coloring book moana                                  January 15, 2018
# U Launcher Lite – FREE Live Cool Themes, Hide Apps     August 1, 2018
# Sketch - Draw & Paint                                    June 8, 2018
# Pixel Draw - Number Art Coloring Book                   June 20, 2018
# ...                                                               ...
# Xero Accounting Software                                July 30, 2018
# MailChimp - Email, Marketing Automation                 July 25, 2018
# Crew - Free Messaging and Scheduling                    July 20, 2018
# Asana: organize team projects                           July 26, 2018
# Google Analytics                                    February 13, 2018
#
# [250 rows x 9 columns]

# %%
content_id_df = pd.read_excel(data_url,
                              sheet_name='Content_ID',
                              index_col='Content_ID',
                             )

# %%
content_id_df
# Out:
#            Content_Rating
# Content_ID
# 101              Everyone
# 101              Everyone
# 101              Everyone
# 102                  Teen
# 101              Everyone
# ...                   ...
# 101              Everyone
# 101              Everyone
# 101              Everyone
# 101              Everyone
# 101              Everyone
#
# [250 rows x 1 columns]
